# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from cavityclass import *

LAM = 1064*10**(-7)

# %%
laser = Cavity('cavityparts.dat', LAM)
print(laser.cavity)
# Out:
# [['M', 200.0, 0.0], ['D', 37.5], ['M', 0.0, 12.5], ['D', 2.0], ['L', 18.0], ['D', 5.0], ['M', -50.0, 12.5], ['D', 46.0], ['L', 35.0], ['D', 111.4], ['L', 35.0], ['D', 58.0], ['B', 1.5], ['D', 5.0], ['M', -200.0, 0.0]]

# %%
laser.plot_w(250)
# Out:
# Enter M-Squared for x-axis:    1.2
# Enter M-Squared for y-axis:    1.2
# X-Axis
#    Parameter  Rayleigh Range(cm)  Spot Size(microns)  Divergence(mrads)
# M   200.0000           15.897173          509.989902           -0.254995
# D    37.5000           15.897173         1265.152741            2.928318
# M     0.0000           15.897173         1265.152741            2.928318
# D     2.0000           15.897173         1323.968545            2.952708
# L    18.0000            7.781609         1323.968545           -4.402672
# D     5.0000            7.781609         1105.540930           -4.327691
# M   -48.8148           73.792170         1105.540930            0.201841
# D    46.0000           73.792170         1376.109092            0.898579
# L    35.0000           15.342804         1376.109092           -3.033161
# D   111.4000           15.342804         2396.512091            3.183631
# L    35.0000           11.710878         2396.512091           -3.663546
# ...
